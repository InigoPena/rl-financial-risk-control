# %%
import pandas as pd

# %%
df =pd.read_csv("test_trace_dqn.csv")
df.head()
# Out:
#    step  action    reward  total_profit  gold_weight  hedge_weight  drawdown
# 0     0       0  0.002000      0.999000         0.00          0.00  0.001000
# 1     1       0 -0.000303      0.999000         0.00          0.00  0.001000
# 2     2       2  0.001998      0.998001         0.50          0.50  0.001999
# 3     3       5 -0.000309      0.995627         0.25          0.75  0.004373
# 4     4       0 -0.003954      0.992865         0.00          0.00  0.007135

# %%
df["action"].value_counts()
# Out:
# action
# 6    507
# 2    380
# 1    375
# 4    362
# 3    199
# 5     34
# 0     19
# Name: count, dtype: int64
