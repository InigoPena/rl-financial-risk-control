# %%
import pandas as pd

# %%
df =pd.read_csv("test_trace_og.csv")
df.head()
# Out:
#    step  action    reward  total_profit  gold_weight  hedge_weight  drawdown
# 0     0       1  0.002000      0.999000          NaN           NaN       NaN
# 1     1       3 -0.000303      0.997222          NaN           NaN       NaN
# 2     2       3 -0.002112      0.999423          NaN           NaN       NaN
# 3     3       3  0.002661      0.998579          NaN           NaN       NaN
# 4     4       3 -0.000629      0.998810          NaN           NaN       NaN

# %%
df["action"].value_counts()
# Out:
# action
# 3    1158
# 6     315
# 1     224
# 4     131
# 5      23
# 2      15
# 0      10
# Name: count, dtype: int64
