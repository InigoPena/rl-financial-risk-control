# %%
import pandas as pd

# %%
df =pd.read_csv("curriculum_runs/test_2015_2020_trace.csv")
df.head()
# Out:
#    step  action    reward  total_profit  gold_weight  hedge_weight  drawdown
# 0     0       0  0.002000      0.999000          NaN           NaN       NaN
# 1     1       1 -0.000303      0.998001          NaN           NaN       NaN
# 2     2       4 -0.000309      0.996286          NaN           NaN       NaN
# 3     3       4 -0.001983      0.994476          NaN           NaN       NaN
# 4     4       4 -0.002571      1.000730          NaN           NaN       NaN

# %%
df["action"].value_counts()
# Out:
# action
# 4    958
# 0    160
# 6    117
# 2      9
# 1      7
# 5      2
# 3      1
# Name: count, dtype: int64
