# %%
import pandas as pd

# %%
df =pd.read_csv("test_trace_curriculum_stageparams.csv")
df.head()
# Out:
#    step  action    reward  total_profit  gold_weight  hedge_weight  drawdown
# 0     0       5  0.002000      0.999000          NaN           NaN       NaN
# 1     1       3 -0.000303      1.002180          NaN           NaN       NaN
# 2     2       0  0.002953      0.996882          NaN           NaN       NaN
# 3     3       4 -0.010246      0.995885          NaN           NaN       NaN
# 4     4       0 -0.001736      1.001153          NaN           NaN       NaN

# %%
df["action"].value_counts()
# Out:
# action
# 4    570
# 6    332
# 0    163
# 3     76
# 5     50
# 2     41
# 1     22
# Name: count, dtype: int64
