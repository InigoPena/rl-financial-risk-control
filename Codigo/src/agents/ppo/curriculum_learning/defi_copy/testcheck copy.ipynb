# %%
import pandas as pd

# %%
df =pd.read_csv("test_trace_curriculum_stageparams.csv")
df.head()
# Out:
#    step  action    reward  total_profit  gold_weight  hedge_weight  drawdown
# 0     0       5  0.002000      0.999000         0.25          0.75  0.001000
# 1     1       5 -0.000303      0.997320         0.25          0.75  0.002680
# 2     2       4 -0.001886      0.996137         1.00          0.00  0.003863
# 3     3       4 -0.000760      0.995829         1.00          0.00  0.004171
# 4     4       4  0.000952      0.997058         1.00          0.00  0.002942

# %%
df["action"].value_counts()
# Out:
# action
# 4    1112
# 6     426
# 0     136
# 5     100
# 2      77
# 1      16
# 3       9
# Name: count, dtype: int64
